# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('sports.csv', index_col=0)
df
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
df.plot()

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh')

# %%
df.plot(kind='bar', stacked=True)

# %% [markdown]
# * 여자에 대한 정보만 받아오고 싶을 때

# %%
df['Female']
# Out:
# Swimming      178
# Baseball      289
# Basketball     97
# Golf          232
# Soccer        109
# Bowling       129
# Name: Female, dtype: int64

# %%
df['Female'].plot(kind='bar')
