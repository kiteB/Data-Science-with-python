# %%
import pandas as pd
import seaborn as sns

# %%
body_df = pd.read_csv('body.csv', index_col=0)
body_df.head()
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
body_df.plot(kind='scatter', x='Height', y='Weight')

# %%
sns.lmplot(data=body_df, x='Height', y='Weight')

# %% [markdown]
# * 회귀선: 흩어져있는 점들을 하나의 선으로 표현하기 위한 것

# %% [markdown]
# * 선에 포함되지 않은 점들이 훨씬 많음!
# -> Why? 키와 몸무게가 그렇게 큰 연관성을 가지고 있지 않기 때문!
