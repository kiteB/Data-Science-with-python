# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('survey.csv')
df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...  Spending on looks  \
# 0      1.0  5.0   5.0                1.0  ...                3.0
# 1      2.0  3.0   5.0                4.0  ...                2.0
# 2      5.0  3.0   5.0                3.0  ...                3.0
# 3      1.0  2.0   2.0                1.0  ...                4.0
# 4      3.0  5.0   3.0                1.0  ...                3.0
#
#    Spending on gadgets  Spending on healthy eating   Age  Height  Weight  \
# ...

# %%
movie = df.loc[:, 'Horror':'Action']

# %%
movie.head()
# Out:
#    Horror  Thriller  Comedy  Romantic  Sci-fi  War  Fantasy/Fairy tales  \
# 0     4.0       2.0     5.0       4.0     4.0  1.0                  5.0
# 1     2.0       2.0     4.0       3.0     4.0  1.0                  3.0
# 2     3.0       4.0     4.0       2.0     4.0  2.0                  5.0
# 3     4.0       4.0     3.0       3.0     4.0  3.0                  1.0
# 4     4.0       4.0     5.0       2.0     3.0  3.0                  4.0
#
#    Animated  Documentary  Western  Action
# 0       5.0          3.0      1.0     2.0
# 1       5.0          4.0      1.0     4.0
# 2       5.0          2.0      2.0     1.0
# 3       2.0          5.0      1.0     2.0
# 4       4.0          3.0      1.0     4.0

# %%
corr = movie.corr()

# %%
corr
# Out:
#                        Horror  Thriller    Comedy  Romantic    Sci-fi  \
# Horror               1.000000  0.503069  0.098243 -0.128117  0.165834
# Thriller             0.503069  1.000000 -0.008975 -0.164751  0.230838
# Comedy               0.098243 -0.008975  1.000000  0.286236  0.040425
# Romantic            -0.128117 -0.164751  0.286236  1.000000 -0.097219
# Sci-fi               0.165834  0.230838  0.040425 -0.097219  1.000000
# War                  0.136508  0.220754 -0.077274 -0.193751  0.274634
# Fantasy/Fairy tales -0.087150 -0.090075  0.211025  0.349432 -0.009158
# Animated             0.004865 -0.025239  0.180246  0.239951  0.068642
# Documentary         -0.063749  0.046558 -0.007444 -0.083895  0.141714
# Western              0.078845  0.124719 -0.033091 -0.126574  0.276898
# Action               0.129958  0.278214  0.121256 -0.181823  0.363429
#
#                           War  Fantasy/Fairy tales  Animated  Documentary  \
# ...

# %%
sns.clustermap(corr)
